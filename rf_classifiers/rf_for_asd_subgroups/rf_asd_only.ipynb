# %%
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier 
import pickle

# %% [markdown]
# ## Load data

# %%
k_scale = 0.1
results_folder = f'asd_only_louvain_results_knn_weighted/k_scale_{k_scale}'

def get_cluster_df(sample_size, i, drop_asd = True):
    folder_path = f"{results_folder}/{sample_size}/{i}"
    df = pd.read_pickle(f"{folder_path}/sample_df.pkl")
    if "index" in df.columns:
        df = df.drop("index", axis=1)
    score_cols = ['dcdq_score', 'rbsr_score', 'scq_score']
    df = df.drop(score_cols, axis=1)
    if drop_asd:
        df = df.drop("asd", axis=1)
    return df

def get_communinies(sample_size, i ):
    folder_path = f"{results_folder}/{sample_size}/{i}"
    with open(f"{folder_path}/communities.pkl", 'rb') as file:
        communities = pickle.load(file)
    return communities

# %%
spark_df = get_cluster_df(22274, 0)
spark_communities = get_communinies(22274, 0)

# %%
print(len(spark_communities))
# Out:
# 5

# %%
# check check number of null values in each field
spark_df.apply(lambda x: x.isnull().sum())
# Out:
# dev_lang                       0
# dev_lang_dis                   0
# sex                            0
# attn_behav                     0
# dev_speech                     0
# dev_soc_prag                   0
# birth_oth_calc                 0
# dev_motor                      0
# behav_adhd                     0
# dev_ld                         0
# neuro_oth_calc                 0
# psych_oth_calc                 0
# behav_odd                      0
# mood_dep                       0
# mood_soc_anx                   0
# mood_anx                       0
# mood_ocd                       0
# mood_sep_anx                   0
# mood_dmd                       0
# mood_bipol                     0
# multiple_birth                 0
# mood_or_anx                    0
# gen_dx_oth_calc_self_report    0
# mood_hoard                     0
# behav_intermitt_explos         0
# behav_conduct                  0
# dev_mutism                     0
# cluster                        0
# dtype: int64

# %%
# create dataset
# target_var = 'asd'
target_var = 'cluster'
feature_space = spark_df.iloc[:, spark_df.columns != 'cluster']
feature_class = spark_df.iloc[:, spark_df.columns == 'cluster']

# train_test_split in a stratified manner
X_train, X_test, y_train, y_test = train_test_split(feature_space,
                                                                    feature_class,
                                                                    test_size = 0.20, 
                                                                    random_state = 42)
# X_train, X_test, y_train, y_test

# Cleaning test sets to avoid future warning messages
y_train = y_train.values.ravel() 
y_test = y_test.values.ravel()

# %%
set(y_train)
# Out:
# {0, 1, 2, 3, 4}

# %%
from collections import Counter

def print_value_counts(y, dataset_name):
    counter = Counter(y)
    total = len(y)
    print(f"Value counts for {dataset_name}:")
    for value in sorted(counter.keys()):  # Sort the keys before iterating
        count = counter[value]
        percentage = (count / total) * 100
        print(f"Value {value}: {count} times ({percentage:.2f}%)")
    print()

print_value_counts(y_train, "y_train")
print_value_counts(y_test, "y_test")
# Out:
# Value counts for y_train:
# Value 0: 2849 times (15.99%)
# Value 1: 4209 times (23.62%)
# Value 2: 5052 times (28.35%)
# Value 3: 3024 times (16.97%)
# Value 4: 2685 times (15.07%)
#
# Value counts for y_test:
# Value 0: 742 times (16.66%)
# Value 1: 1077 times (24.18%)
# Value 2: 1246 times (27.97%)
# Value 3: 777 times (17.44%)
# Value 4: 613 times (13.76%)

# %%
# instantiate classifier 
rf_classifier = RandomForestClassifier(random_state=42, n_estimators=10)

# %% [markdown]
# ## Parameter grid search

# %%
np.random.seed(42)
start = time.time()

# give to GridSearchCV

param_dist = {'max_depth': [5, 10, 20],
 'bootstrap': [True, False],
 'max_features': ['sqrt', 'log2'],
 'criterion': ['gini', 'entropy'],
 'n_estimators': [20, 100, 200]}

# param_dist = {'max_depth': [5, 20],
#  'bootstrap': [True],
#  'max_features': ['sqrt'],
#  'criterion': ['gini'],
#  'n_estimators': [20]}

param_dist = {'max_depth': [2, 5, 10, 20, None],
 'bootstrap': [True, False],
 'max_features': ['sqrt', 'log2'],
 'criterion': ['gini', 'entropy'],
 'n_estimators': [10, 20, 40, 80, 100, 200, 500]}

# set up the GridSearch
cv_rf = GridSearchCV(rf_classifier, cv = 5,
                     param_grid=param_dist, 
                     n_jobs = 3, return_train_score=True)

# fit the GridSearch
cv_rf.fit(X_train, y_train)
print('Best Parameters using grid search: \n', cv_rf.best_params_)


end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Best Parameters using grid search:
#  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
# Time taken in grid search:  265.49

# %%
print("Best parameters:", cv_rf.best_params_)
print("Best score:", cv_rf.best_score_)
# Out:
# Best parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
# Best score: 1.0

# %%
cv_rf.cv_results_['mean_train_score'][cv_rf.best_index_]
# Out:
# 1.0

# %%
cv_results = cv_rf.cv_results_
for mean_score, params in zip(cv_results["mean_test_score"], cv_results["params"]):
    print("Mean Score:", mean_score)
    print("Parameters:", params)
    print("---")
# Out:
# Mean Score: 0.9413546542230234
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.912621269923169
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 0.9145856072182201
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 0.93636025014545
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 0.9489314985385713
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 0.938605139554714
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 0.9356304650017814
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.7980232360716971
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.8313584436374221
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.8433127545766708
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.8433128805754869
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.8515063158481627
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 0.8698576654372333
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 0.84415472591635
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9864194065896751
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9892253214781046
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9506146379754762
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9861947822000212
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.9841744226812988
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.9859139308386198
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.9882709906940423
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9966884991115508
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9999438832772167
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9999438832772167
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9998877665544331
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9998877665544332
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9450024774517243
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9184580548365748
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 0.9163252728740614
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 0.9334419915624894
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 0.948650757426134
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 0.9532524546931882
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 0.9344520138233301
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.8112682158851119
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.8808014501203761
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.8513382334272969
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.8577920345438355
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.8566134731164201
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 0.8719341416787391
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 0.8433127860763747
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9842303504058579
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9889444228671472
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9536446417585906
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9877098392160606
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.9808072775656272
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.992086912093461
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.9980918266772884
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9985408864583716
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9997755331088666
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9998316498316498
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9999438832772167
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9395026291227992
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9093102572801328
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 0.9145856072182201
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 0.9365846697870273
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 0.9476964108922197
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 0.9380436730796914
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 0.9383243511927205
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.7867998915150192
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.8096972153946613
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.8353441326918734
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.8398336280130648
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.8483637478725887
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 0.8682302332269588
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 0.8439864544972601
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9950056116722784
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9955664481532196
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9490432594885772
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9788989939939514
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.9735675115832286
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.9859139623383237
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.9863067793978075
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9947245240630964
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9998877665544331
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9999438832772167
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9999438675273646
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'gini', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9380996638036587
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9224423579040476
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 0.9155956924784693
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 0.9333858590898538
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 0.9446100383886893
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 0.9451709221191866
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 0.9345081462959655
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.8112120991623284
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.8796223689478438
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.849766933689658
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.8580164069358567
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.8576234796274089
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 0.8709239304196738
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 0.84449126875453
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 0.9938831827174983
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 0.9957347983215697
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9516809344576208
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 0.9768229272485985
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 0.9722771892058073
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 0.9882147479724429
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 0.9903473409367318
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9984845964872159
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 0.9998877665544331
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 500}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 10}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 20}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 40}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 80}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 100}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# ---
# Mean Score: 1.0
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'log2', 'n_estimators': 500}
# ---

# %%
# with open('cv_rf_more_features.pickle', 'rb') as file:
#     # Unpickle the object
#     cv = pickle.load(file)

# %% [markdown]
# ## Fitting best classifier

# %%
best_params = {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 40}
rf_classifier.set_params(**best_params)
# best score: 1

# rf_classifier.set_params(**cv_rf.best_params_)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=40, random_state=42)

# %%
# fit the Random forest to the training data
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=40, random_state=42)

# %%
# returns a dict with value pairs {importance: indices} for printing
def variable_importance(fit):
    try:
        # Checks whether first parameter is a model
        if not hasattr(fit, 'fit'):
            return print("'{0}' is not an instantiated model from scikit-learn".format(fit)) 

        # Checks whether model has been trained
        if not vars(fit)["estimators_"]:
            return print("Model does not appear to be trained.")
    except KeyError:
        print("Model entered does not contain 'estimators_' attribute.")

    importances = fit.feature_importances_
    # sort from most import to least
    indices = np.argsort(importances)[::-1]
    return {'importance': importances,
            'index': indices}

# %%
# get variable importance and their indexes
rf_var_imp = variable_importance(rf_classifier)

rf_importances = rf_var_imp['importance']

rf_indices = rf_var_imp['index']

# %%
names_index = X_train.columns
sorted_feature_names = [names_index[i] for i in rf_indices]
sorted_improtances = [rf_importances[i] for i in rf_indices]
sorted_feature_importances_df = pd.DataFrame({'feature': sorted_feature_names, 'importance': sorted_improtances})
sorted_feature_importances_df
# pd.to_pickle(sorted_feature_importances_df, 'sorted_feature_importances_RF_mf_newest.pkl')
# Out:
#                         feature  importance
# 0                  dev_lang_dis    0.254998
# 1                    attn_behav    0.243913
# 2                      dev_lang    0.193622
# 3                    behav_adhd    0.162567
# 4                    dev_speech    0.046107
# 5                        dev_ld    0.025057
# 6                  dev_soc_prag    0.017830
# 7                     dev_motor    0.016704
# 8                   mood_or_anx    0.011782
# 9                     behav_odd    0.011617
# 10                     mood_anx    0.004548
# 11                     mood_dep    0.002990
# 12                     mood_ocd    0.001659
# 13                 mood_soc_anx    0.001612
# 14                     mood_dmd    0.001416
# 15                behav_conduct    0.000791
# 16               psych_oth_calc    0.000580
# 17       behav_intermitt_explos    0.000563
# 18                 mood_sep_anx    0.000474
# 19                          sex    0.000264
# 20                   dev_mutism    0.000252
# 21  gen_dx_oth_calc_self_report    0.000199
# 22                   mood_bipol    0.000161
# 23               multiple_birth    0.000125
# 24               neuro_oth_calc    0.000092
# 25                   mood_hoard    0.000042
# 26               birth_oth_calc    0.000037

# %%
# unpacks and prints values in importance dict according to the index 
def print_var_importance(importance, indices, names_index=X_train.columns):
    print("Feature ranking:")
    # iterate thru variable indices
    for f in range(0, indices.shape[0]):
        i = f
        # prints the name of the feature and its importance metric 
        print("{0}. The feature '{1}' has a Mean Decrease in Impurity of {2:.5f}"
              .format(f + 1, names_index[indices[i]], importance[indices[f]]))

# %%
# get the classes uses to train this model
names_index = feature_space.columns
# names_index = names[2:]

# print out classes by importance in decending order
print_var_importance(rf_importances, rf_indices)
# Out:
# Feature ranking:
# 1. The feature 'dev_lang_dis' has a Mean Decrease in Impurity of 0.25500
# 2. The feature 'attn_behav' has a Mean Decrease in Impurity of 0.24391
# 3. The feature 'dev_lang' has a Mean Decrease in Impurity of 0.19362
# 4. The feature 'behav_adhd' has a Mean Decrease in Impurity of 0.16257
# 5. The feature 'dev_speech' has a Mean Decrease in Impurity of 0.04611
# 6. The feature 'dev_ld' has a Mean Decrease in Impurity of 0.02506
# 7. The feature 'dev_soc_prag' has a Mean Decrease in Impurity of 0.01783
# 8. The feature 'dev_motor' has a Mean Decrease in Impurity of 0.01670
# 9. The feature 'mood_or_anx' has a Mean Decrease in Impurity of 0.01178
# 10. The feature 'behav_odd' has a Mean Decrease in Impurity of 0.01162
# 11. The feature 'mood_anx' has a Mean Decrease in Impurity of 0.00455
# 12. The feature 'mood_dep' has a Mean Decrease in Impurity of 0.00299
# 13. The feature 'mood_ocd' has a Mean Decrease in Impurity of 0.00166
# 14. The feature 'mood_soc_anx' has a Mean Decrease in Impurity of 0.00161
# 15. The feature 'mood_dmd' has a Mean Decrease in Impurity of 0.00142
# 16. The feature 'behav_conduct' has a Mean Decrease in Impurity of 0.00079
# 17. The feature 'psych_oth_calc' has a Mean Decrease in Impurity of 0.00058
# 18. The feature 'behav_intermitt_explos' has a Mean Decrease in Impurity of 0.00056
# 19. The feature 'mood_sep_anx' has a Mean Decrease in Impurity of 0.00047
# 20. The feature 'sex' has a Mean Decrease in Impurity of 0.00026
# 21. The feature 'dev_mutism' has a Mean Decrease in Impurity of 0.00025
# 22. The feature 'gen_dx_oth_calc_self_report' has a Mean Decrease in Impurity of 0.00020
# 23. The feature 'mood_bipol' has a Mean Decrease in Impurity of 0.00016
# 24. The feature 'multiple_birth' has a Mean Decrease in Impurity of 0.00013
# 25. The feature 'neuro_oth_calc' has a Mean Decrease in Impurity of 0.00009
# 26. The feature 'mood_hoard' has a Mean Decrease in Impurity of 0.00004
# 27. The feature 'birth_oth_calc' has a Mean Decrease in Impurity of 0.00004

# %% [markdown]
# ### Feature importance

# %%
# Make a horizontal bar chart to visualize feature importantance

def variable_importance_plot(importance, indices, names_index=X_train.columns, save_path=None):
    index = np.arange(len(names_index))

    importance_desc = sorted(importance)

    feature_space = []

    for i in range(indices.shape[0] - 1, -1, -1):
        feature_space.append(names_index[indices[i]])

    fig, ax = plt.subplots(figsize=(10, 6))

    plt.title('Feature importances for Random Forest model')
    
    plt.barh(index,
              importance_desc,
              align="center",
              color = '#FFB6C1')
    plt.yticks(index,
                feature_space)

    # plt.ylim(-1, 30)
    plt.xlim(0, max(importance_desc) + 0.01)
    plt.xlabel('Mean decrease in impurity')
    plt.ylabel('Feature')
    plt.grid(True, axis='x')

    
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path)
    # plt.savefig('./figures/feature_importance_RF_mf_newest.pdf')

# %%
# variable_importance_plot(rf_importances, rf_indices, save_path='./figures/feature_importance_ASD_subgroups_asd_only_weighted.pdf')
variable_importance_plot(rf_importances, rf_indices)

# %% [markdown]
# ### Cross validation

# %%
# Perform Cross_validation to see how robust our model is 
import time

def cross_val_metrics(fit, X_train, y_train, estimator, print_results = True):
    start = time.time()
    """
    Returns Mean Accurancy with standard_dev of model over Kfolds Validation
    ----------
    scores.mean(): Float representing cross validation score
    scores.std() / 2: Float representing the standard error (derived
                from cross validation score's standard deviation)
    """
    my_estimators = {
    'rf': 'estimators_',
    'nn': 'out_activation_',
    'knn': '_fit_method'
    }
    try:
        # Checks whether first parameter is a model
        if not hasattr(fit, 'fit'):
            return print("'{0}' is not an instantiated model from scikit-learn".format(fit)) 

        # Checks whether the model has been trained
        if not vars(fit)[my_estimators[estimator]]:
            return print("Model does not appear to be trained.")

    except KeyError as e:
        print("'{0}' does not correspond with the appropriate key inside the estimators dictionary. \
              \nPlease refer to function to check `my_estimators` dictionary.".format(estimator))
        raise

    # create KFolds validation
    n = KFold(n_splits=10)

    # record score for each split
    scores = cross_val_score(fit, 
                         X_train, 
                         y_train, 
                         cv = n)
    end = time.time() 
    # print how much time the Kfolds took
    print("Time elapsed to do Cross Validation: {0:.2f} seconds.".format(end-start))
    if print_results:
        for i in range(0, len(scores)):
            # print out the scores for each validation split
            print("Cross validation run {0}: {1: 0.3f}".format(i, scores[i]))

        print("Accuracy: {0: 0.3f} (+/- {1: 0.3f})".format(scores.mean(), scores.std() / 2))     
    else:
        return scores.mean(), scores.std() / 2

# %%
# call cross_val_metrics to see how our model did
cross_val_metrics(rf_classifier, 
                  X_train, 
                  y_train, 
                  'rf',
                  print_results = True)
# Out:
# Time elapsed to do Cross Validation: 1.13 seconds.
# Cross validation run 0:  1.000
# Cross validation run 1:  1.000
# Cross validation run 2:  1.000
# Cross validation run 3:  1.000
# Cross validation run 4:  1.000
# Cross validation run 5:  1.000
# Cross validation run 6:  1.000
# Cross validation run 7:  1.000
# Cross validation run 8:  1.000
# Cross validation run 9:  1.000
# Accuracy:  1.000 (+/-  0.000)

# %%
# make a prediction on test set now that the model has been tuned and validated
rf_predictions = rf_classifier.predict(X_test)

# %%
def create_conf_mat(y_test, predictions):
    """Function returns confusion matrix comparing two arrays"""
    if (len(y_test.shape) != len(predictions.shape) == 1):
        return print('Arrays entered are not 1-D.\nPlease enter the correctly sized sets.')
    elif (y_test.shape != predictions.shape):
        return print('Number of values inside the Arrays are not equal to each other.\nPlease make sure the array has the same number of instances.')
    else:
        # Set Metrics; Compute a simple cross tabulation of two (or more) factors. 
        # By default computes a frequency table of the factors unless an array of values and an aggregation function are passed.
        test_crosstb_comp = pd.crosstab(index = y_test,
                                        columns = predictions)
        # Changed for Future deprecation of as_matrix
        test_crosstb = test_crosstb_comp.values
        return test_crosstb

# %%
conf_mat = create_conf_mat(y_test, rf_predictions)

# use seaborn heatmap
sns.heatmap(conf_mat, annot=True, fmt='d', cbar=True)
# plt.xlabel('Predicted Values')
# plt.ylabel('Actual Values')
# plt.title('Actual vs. Predicted Confusion Matrix')
plt.show()

conf_mat
# Out:
# array([[ 742,    0,    0,    0,    0],
#        [   0, 1077,    0,    0,    0],
#        [   0,    0, 1246,    0,    0],
#        [   0,    0,    0,  777,    0],
#        [   0,    0,    0,    0,  613]])

# %% [markdown]
# ## Test set performance

# %%
# use built in score function to get accurancy of this model against the test set
rf_accuracy = rf_classifier.score(X_test, y_test)

print("Here is our mean accuracy on the test set:\n {0:.4f}"\
      .format(rf_accuracy))
# Out:
# Here is our mean accuracy on the test set:
#  1.0000

# %%
# Here we calculate the test error rate!
rf_test_error_rate = 1 - rf_accuracy
print("The test error rate for our model is:\n {0: .4f}"\
      .format(rf_test_error_rate))
# Out:
# The test error rate for our model is:
#   0.0000

# %% [markdown]
# Set up for ROC (receiver operating characteristic) curve which calculates the false positive rates and true positive rates across different thresholds.
#
# An ideal model will have a false positive rate of 0 and true positive rate of 1. Most the curve will be in the top left corner of the graph.
#
# On the other hand, a ROC curve that is at 45 degrees is indicative of a model that is essentially randomly guessing. Most of the curve will be in the middle of the graph.

# %%
# predict_proba returns two arrays that represent the predicted_prob of negative class and positive class respectively.

# I just want to take the positive classes in this instance
predictions_prob = rf_classifier.predict_proba(X_test)[:, 1]

# use roc_curve to produce 
fpr2, tpr2, _ = roc_curve(y_test,
                          predictions_prob,
                          pos_label = 1)

auc_rf = auc(fpr2, tpr2)

print(auc_rf)
# Out:
# 1.0

# %%
def plot_roc_curve(fpr, tpr, auc, estimator, xlim=None, ylim=None):
    """
    Purpose
    ----------
    Function creates ROC Curve for respective model given selected parameters.
    Optional x and y limits to zoom into graph

    Parameters
    ----------
    * fpr: Array returned from sklearn.metrics.roc_curve for increasing
            false positive rates
    * tpr: Array returned from sklearn.metrics.roc_curve for increasing
            true positive rates
    * auc: Float returned from sklearn.metrics.auc (Area under Curve)
    * estimator: String represenation of appropriate model, can only contain the
    following: ['knn', 'rf', 'nn']
    * xlim: Set upper and lower x-limits
    * ylim: Set upper and lower y-limits
    """
    my_estimators = {'knn': ['Kth Nearest Neighbor', 'deeppink'],
              'rf': ['Random Forest', 'red'],
              'nn': ['Neural Network', 'purple']}

    try:
        plot_title = my_estimators[estimator][0]
        color_value = my_estimators[estimator][1]
    except KeyError as e:
        print("'{0}' does not correspond with the appropriate key inside the estimators dictionary. \
\nPlease refer to function to check `my_estimators` dictionary.".format(estimator))
        raise

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_facecolor('#fafafa')

    plt.plot(fpr, tpr,
             color=color_value,
             linewidth=1)
    plt.title('ROC Curve For {0} (AUC = {1: 0.3f})'\
              .format(plot_title, auc))

    plt.plot([0, 1], [0, 1], 'k--', lw=2) # Add Diagonal line
    plt.plot([0, 0], [1, 0], 'k--', lw=2, color = 'black')
    plt.plot([1, 0], [1, 1], 'k--', lw=2, color = 'black')
    if xlim is not None:
        plt.xlim(*xlim)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.show()
    plt.close()

# %%
plot_roc_curve(fpr2, tpr2, auc_rf, 'rf',
               xlim=(-0.01, 1.05), 
               ylim=(0.001, 1.05))
# Out:
# /tmp/ipykernel_1235054/2153116955.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0, 0], [1, 0], 'k--', lw=2, color = 'black')
# /tmp/ipykernel_1235054/2153116955.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([1, 0], [1, 1], 'k--', lw=2, color = 'black')

# %%
# # zoom in
# plot_roc_curve(fpr2, tpr2, auc_rf, 'rf', 
#                xlim=(-0.01, 0.2), 
#                ylim=(0.85, 1.01))

# %%
def print_class_report(predictions, alg_name):
    # print some title
    print('Classification Report for {0}:'.format(alg_name))
    # print class report metrics for each target 
    print(classification_report(predictions, 
            y_test, 
            target_names = [str(i) for i in np.unique(predictions)]))

# %%
class_report = print_class_report(rf_predictions, 'Random Forest')
# Out:
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       742
#            1       1.00      1.00      1.00      1077
#            2       1.00      1.00      1.00      1246
#            3       1.00      1.00      1.00       777
#            4       1.00      1.00      1.00       613
#
#     accuracy                           1.00      4455
#    macro avg       1.00      1.00      1.00      4455
# weighted avg       1.00      1.00      1.00      4455
